# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\dipesh.shrestha\Documents\neuronepal\mental-navigation-meg\mental-navigation-press\data\DEV_006\1\2025_07_12_05_06\beh\r1.csv")

# %%
df.head(10)
# Out:
#    subjectId  runTrialId  run  startCatPos  startId  blockId  runBlockId  \
# 0          1           1    1            2        5        1           1
# 1          1           2    1            1        1        1           1
# 2          1           3    1            1       13        1           1
# 3          1           4    1            2        8        1           1
# 4          1           5    1            1       16        1           1
# 5          1           6    1            1       10        1           1
# 6          1           7    1            2        2        2           2
# 7          1           8    1            3        9        2           2
# 8          1           9    1            1       13        2           2
# 9          1          10    1            1       10        2           2
#
#    speed  distance  startCat  ...       itiOnset      itiOffset  \
# 0    1.2        12         2  ...  140206.952382  140208.976186
# ...
